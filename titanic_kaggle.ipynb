# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
train_pd = pd.read_csv('train.csv')
test_pd = pd.read_csv('test.csv')

# %%
train_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
survived = train_pd['Survived']
train_pd = train_pd.drop(['Survived'], axis =1)

# %%
train_pd
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
train_idx = train_pd['PassengerId']
test_idx = test_pd['PassengerId']

#combine dataframes

combined_pd = pd.concat([train_pd,test_pd]).reset_index(drop=True)

# %%
display(combined_pd)
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0       male  22.0      1      0           A/5 21171    7.2500   NaN        S
# 1     female  38.0      1      0            PC 17599   71.2833   C85        C
# 2     female  26.0      0      0    STON/O2. 3101282    7.9250   NaN        S
# 3     female  35.0      1      0              113803   53.1000  C123        S
# 4       male  35.0      0      0              373450    8.0500   NaN        S
# ...      ...   ...    ...    ...                 ...       ...   ...      ...
# 1304    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1305  female  39.0      0      0            PC 17758  108.9000  C105        C
# 1306    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307    male   NaN      0      0              359309    8.0500   NaN        S
# 1308    male   NaN      1      1                2668   22.3583   NaN        C
#
# [1309 rows x 11 columns]

# %% [markdown]
# # Missing values

# %%
#missing value investigation

print('NULL VALUES:')
print(combined_pd.isnull().sum())
# Out:
# NULL VALUES:
# PassengerId       0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
y= combined_pd['Age'].value_counts()
x = y.index.values

plt.figure (figsize=(10,5))
plt.bar(x,y)
plt.title('All ages')
plt.show()

#yaşların sınıflara göre dağılımını incelemek amacıyla

class_age = combined_pd[['Pclass','Age']]

for i in range (1,4):
    plt.figure (figsize=(10,5))
    plt.title('Class ' + str(i))
    y = class_age[class_age['Pclass']==i]['Age'].value_counts()
    x = y.index.values
    plt.bar(x,y)
    plt.show()

medians = class_age.groupby('Pclass').median()
print(medians)
# Out:
#          Age
# Pclass
# 1       39.0
# 2       29.0
# 3       24.0

# %% [markdown]
# # Yaş dağılımı
#
# Classlara göre median değerleri verildiği için bütün dataset'in medianını almak yerine classlara göre alıp boşlukları doldurma yapılacak

# %%
for i in range(3):
    idx = np.where((combined_pd['Pclass']==i+1)&(combined_pd['Age'].isnull()))[0]
    combined_pd.loc[idx,'Age'] = medians.values[i][0]

display(combined_pd)
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0       male  22.0      1      0           A/5 21171    7.2500   NaN        S
# 1     female  38.0      1      0            PC 17599   71.2833   C85        C
# 2     female  26.0      0      0    STON/O2. 3101282    7.9250   NaN        S
# 3     female  35.0      1      0              113803   53.1000  C123        S
# 4       male  35.0      0      0              373450    8.0500   NaN        S
# ...      ...   ...    ...    ...                 ...       ...   ...      ...
# 1304    male  24.0      0      0           A.5. 3236    8.0500   NaN        S
# 1305  female  39.0      0      0            PC 17758  108.9000  C105        C
# 1306    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307    male  24.0      0      0              359309    8.0500   NaN        S
# 1308    male  24.0      1      1                2668   22.3583   NaN        C
#
# [1309 rows x 11 columns]

# %%
print('NULL VALUES:')
print(combined_pd.isnull().sum())
# Out:
# NULL VALUES:
# PassengerId       0
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %% [markdown]
# 'Fare' kısmında 1 missing value gözüküyor onu incelemek istiyoruz

# %%
display(combined_pd[combined_pd['Fare'].isnull()])
# Out:
#       PassengerId  Pclass                Name   Sex   Age  SibSp  Parch  \
# 1043         1044       3  Storey, Mr. Thomas  male  60.5      0      0
#
#      Ticket  Fare Cabin Embarked
# 1043   3701   NaN   NaN        S

# %% [markdown]
# # How to get Fare value
# Akla ilk gelen yöntem Embarked ile Pclass'ı eşleşen diğer verilerin mean değerlerini almak yaklaşık bir sonuç verecektir.

# %%
display(combined_pd[combined_pd['Fare'].isnull()])

sim_fares = combined_pd[(combined_pd['Pclass']== 3 )&(combined_pd['Embarked']=='S')]['Fare']
print('Median:', sim_fares.median())

plt.hist(sim_fares)
plt.plot()

combined_pd['Fare'].fillna(sim_fares.median(), inplace  =True)
# Out:
#       PassengerId  Pclass                Name   Sex   Age  SibSp  Parch  \
# 1043         1044       3  Storey, Mr. Thomas  male  60.5      0      0
#
#      Ticket  Fare Cabin Embarked
# 1043   3701   NaN   NaN        S
# Median: 8.05
# C:\Users\Hp\AppData\Local\Temp\ipykernel_12576\2855396593.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_pd['Fare'].fillna(sim_fares.median(), inplace  =True)

# %%
#missing value investigation

print('NULL VALUES:')
print(combined_pd.isnull().sum())
# Out:
# NULL VALUES:
# PassengerId       0
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          2
# dtype: int64
